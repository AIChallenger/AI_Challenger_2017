# %%
# %matplotlib inline
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap
import matplotlib.pyplot as plt
import skimage.io as io
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

import json
from json import encoder
encoder.FLOAT_REPR = lambda o: format(o, '.3f')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-9e08556e0e1f> in <module>()
#       1 #%matplotlib inline
# ----> 2 from pycocotools.coco import COCO
#       3 from pycocoevalcap.eval import COCOEvalCap
#       4 import matplotlib.pyplot as plt
#       5 import skimage.io as io
#
# /home/zh/coco-caption/pycocotools/coco.py in <module>()
#      50 from matplotlib.patches import Polygon
#      51 import numpy as np
# ---> 52 from skimage.draw import polygon
#      53 import copy
#      54
#
# ImportError: No module named 'skimage'

# %%
# set up file names and pathes
dataDir='.'
dataType='val2014'
algName = 'fakecap'
annFile='%s/annotations/captions_%s.json'%(dataDir,dataType)
subtypes=['results', 'evalImgs', 'eval']
[resFile, evalImgsFile, evalFile]= \
['%s/results/captions_%s_%s_%s.json'%(dataDir,dataType,algName,subtype) for subtype in subtypes]

# %%
# create coco object and cocoRes object
coco = COCO(annFile)
cocoRes = coco.loadRes(resFile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0f109428dc37> in <module>()
#       1 # create coco object and cocoRes object
# ----> 2 coco = COCO(annFile)
#       3 cocoRes = coco.loadRes(resFile)
#
# NameError: name 'COCO' is not defined

# %%
# create cocoEval object by taking coco and cocoRes
cocoEval = COCOEvalCap(coco, cocoRes)

# evaluate on a subset of images by setting
# cocoEval.params['image_id'] = cocoRes.getImgIds()
# please remove this line when evaluating the full validation set
cocoEval.params['image_id'] = cocoRes.getImgIds()

# evaluate results
cocoEval.evaluate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c5629f586279> in <module>()
#       1 # create cocoEval object by taking coco and cocoRes
# ----> 2 cocoEval = COCOEvalCap(coco, cocoRes)
#       3
#       4 # evaluate on a subset of images by setting
#       5 # cocoEval.params['image_id'] = cocoRes.getImgIds()
#
# NameError: name 'COCOEvalCap' is not defined

# %%
# print output evaluation scores
for metric, score in cocoEval.eval.items():
    print '%s: %.3f'%(metric, score)
# Out:
#   File "<ipython-input-10-ab6a2078c320>", line 3
#     print '%s: %.3f'%(metric, score)
#                    ^
# SyntaxError: invalid syntax

# %%
# demo how to use evalImgs to retrieve low score result
evals = [eva for eva in cocoEval.evalImgs if eva['CIDEr']<30]
print 'ground truth captions'
imgId = evals[0]['image_id']
annIds = coco.getAnnIds(imgIds=imgId)
anns = coco.loadAnns(annIds)
coco.showAnns(anns)

print '\n'
print 'generated caption (CIDEr score %0.1f)'%(evals[0]['CIDEr'])
annIds = cocoRes.getAnnIds(imgIds=imgId)
anns = cocoRes.loadAnns(annIds)
coco.showAnns(anns)

img = coco.loadImgs(imgId)[0]
I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
plt.imshow(I)
plt.axis('off')
plt.show()
# Out:
#   File "<ipython-input-11-f705b289e018>", line 3
#     print 'ground truth captions'
#                                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
# plot score histogram
ciderScores = [eva['CIDEr'] for eva in cocoEval.evalImgs]
plt.hist(ciderScores)
plt.title('Histogram of CIDEr Scores', fontsize=20)
plt.xlabel('CIDEr score', fontsize=20)
plt.ylabel('result counts', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a20009b39c49> in <module>()
#       1 # plot score histogram
# ----> 2 ciderScores = [eva['CIDEr'] for eva in cocoEval.evalImgs]
#       3 plt.hist(ciderScores)
#       4 plt.title('Histogram of CIDEr Scores', fontsize=20)
#       5 plt.xlabel('CIDEr score', fontsize=20)
#
# NameError: name 'cocoEval' is not defined

# %%
# save evaluation results to ./results folder
json.dump(cocoEval.evalImgs, open(evalImgsFile, 'w'))
json.dump(cocoEval.eval,     open(evalFile, 'w'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2a07e22759b2> in <module>()
#       1 # save evaluation results to ./results folder
# ----> 2 json.dump(cocoEval.evalImgs, open(evalImgsFile, 'w'))
#       3 json.dump(cocoEval.eval,     open(evalFile, 'w'))
#
# NameError: name 'json' is not defined
